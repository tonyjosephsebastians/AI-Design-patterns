# %% [markdown]
# <a href="https://colab.research.google.com/github/tonyjosephsebastians/AI-Design-patterns/blob/main/Metadata_First_Retrieval_Pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://arxiv.org/html/2601.11863v1

# %% [markdown]
# https://www.emergentmind.com/topics/metadata-aware-retrieval-strategies

# %% [markdown]
# https://haystack.deepset.ai/blog/extracting-metadata-filter
