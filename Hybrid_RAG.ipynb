# %% [markdown]
# <a href="https://colab.research.google.com/github/tonyjosephsebastians/AI-Design-patterns/blob/main/Hybrid_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://arxiv.org/abs/2412.16311

# %% [markdown]
# https://haystack.deepset.ai/tutorials/33_hybrid_retrieval

# %% [markdown]
# https://haystack.deepset.ai/blog/hybrid-retrieval
