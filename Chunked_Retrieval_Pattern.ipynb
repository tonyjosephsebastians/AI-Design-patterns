# %% [markdown]
# <a href="https://colab.research.google.com/github/tonyjosephsebastians/AI-Design-patterns/blob/main/Chunked_Retrieval_Pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.firecrawl.dev/blog/best-chunking-strategies-rag-2025

# %% [markdown]
# https://weaviate.io/blog/chunking-strategies-for-rag

# %% [markdown]
# https://www.f22labs.com/blogs/7-chunking-strategies-in-rag-you-need-to-know/

# %% [markdown]
# https://research.trychroma.com/evaluating-chunking

# %% [markdown]
# https://superlinked.com/vectorhub/articles/evaluation-rag-retrieval-chunking-methods

# %% [markdown]
# https://developer.nvidia.com/blog/finding-the-best-chunking-strategy-for-accurate-ai-responses/
