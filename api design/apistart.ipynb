# %%
pip install fastapi
# Out:
# Collecting fastapi
#   Downloading fastapi-0.131.0-py3-none-any.whl (103 kB)
#                                               0.0/103.9 kB ? eta -:--:--
#      -------------------------------------- 103.9/103.9 kB 3.0 MB/s eta 0:00:00
# Collecting starlette<1.0.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
#                                               0.0/74.3 kB ? eta -:--:--
#      ---------------------------------------- 74.3/74.3 kB ? eta 0:00:00
# Collecting pydantic>=2.7.0 (from fastapi)
#   Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\tony\appdata\roaming\python\python311\site-packages (from fastapi) (4.11.0)
# Collecting typing-inspection>=0.4.2 (from fastapi)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.7.0->fastapi)
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.7.0->fastapi)
#   Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
#                                               0.0/2.0 MB ? eta -:--:--
#      -----                                    0.3/2.0 MB 5.9 MB/s eta 0:00:01
#      ----------                               0.6/2.0 MB 7.0 MB/s eta 0:00:01
#      ----------------                         0.8/2.0 MB 7.3 MB/s eta 0:00:01
#      ---------------------                    1.1/2.0 MB 6.2 MB/s eta 0:00:01
#      --------------------------               1.3/2.0 MB 6.5 MB/s eta 0:00:01
#      --------------------------------         1.7/2.0 MB 6.6 MB/s eta 0:00:01
#      --------------------------------------   2.0/2.0 MB 6.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 6.4 MB/s eta 0:00:00
# Collecting typing-extensions>=4.8.0 (from fastapi)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting anyio<5,>=3.6.2 (from starlette<1.0.0,>=0.40.0->fastapi)
#   Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.6.2->starlette<1.0.0,>=0.40.0->fastapi)
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Installing collected packages: typing-extensions, idna, annotated-types, annotated-doc, typing-inspection, pydantic-core, anyio, starlette, pydantic, fastapi
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.12.1 fastapi-0.131.0 idna-3.11 pydantic-2.12.5 pydantic-core-2.41.5 starlette-0.52.1 typing-extensions-4.15.0 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script fastapi.exe is installed in 'c:\Users\TONY\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install uvicorn
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: uvicorn in c:\users\tony\appdata\local\programs\python\python311\lib\site-packages (0.41.0)
# Requirement already satisfied: click>=7.0 in c:\users\tony\appdata\local\programs\python\python311\lib\site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\tony\appdata\local\programs\python\python311\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\tony\appdata\roaming\python\python311\site-packages (from click>=7.0->uvicorn) (0.4.6)
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from fastapi import FastAPI

app = FastAPI(title = " a samll fastapi")

@app.get("/")
def read_root():
    return {"message":"Hello from fastapi"}

@app.get("/health")
def health():
    return {"status":"ok"}

# %%
# !pip install fastapi uvicorn
# Out:
# Requirement already satisfied: fastapi in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (0.115.6)
# Requirement already satisfied: uvicorn in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (0.30.6)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from fastapi) (0.41.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from fastapi) (2.10.6)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: click>=7.0 in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: colorama in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.27.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from starlette<0.42.0,>=0.40.0->fastapi) (4.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (3.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\tony\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (1.3.1)
# DEPRECATION: Loading egg at c:\users\tony\appdata\local\programs\python\python312\lib\site-packages\yahoo_ticker_downloader-3.0.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: C:\Users\TONY\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
